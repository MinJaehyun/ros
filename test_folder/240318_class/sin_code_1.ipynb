# %% [markdown]
# ### 삼각 함수를 그래프로 나타냄

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
t = np.arange(0, 6, 0.01)

# %%
t.shape
# Out:
# (600,)

# %% [markdown]
# ### 삼각 함수: y=Asin(2ㅠft) + b

# %%
y = np.sin(np.pi * t)

# %%
y.shape
# Out:
# (600,)

# %%
plt.figure(figsize=(12, 6))

# %%
plt.plot(t, y)

# %%
plt.grid()

# %%
plt.show()
